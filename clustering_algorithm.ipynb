# %% [markdown]
# <a href="https://colab.research.google.com/github/lovelessbhartal12/machine-learning-codebase/blob/main/clustering_algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_blobs

# %%
x,y = make_blobs(n_samples=100, centers=2, n_features=2, random_state=0)

# %%
from sklearn.cluster import KMeans
K=5
kmeans=KMeans(n_clusters=K)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=5)

# %%
y_pred=kmeans.predict(x)

# %%
y_pred
# Out:
# array([4, 1, 2, 2, 4, 0, 2, 4, 2, 1, 2, 1, 3, 2, 1, 4, 4, 2, 1, 1, 3, 2,
#        0, 2, 4, 3, 1, 3, 3, 0, 4, 3, 1, 4, 0, 0, 1, 0, 0, 1, 2, 3, 2, 0,
#        0, 4, 1, 1, 2, 3, 1, 1, 3, 3, 0, 3, 0, 1, 4, 4, 1, 0, 2, 4, 3, 0,
#        2, 0, 4, 0, 0, 1, 4, 3, 2, 2, 1, 4, 2, 3, 0, 0, 2, 3, 2, 2, 4, 3,
#        1, 4, 4, 4, 1, 1, 0, 2, 1, 4, 2, 1], dtype=int32)

# %%
y_pred is kmeans.labels_
# Out:
# False

# %%
kmeans.cluster_centers_
# Out:
# array([[1.87530301, 3.17760813],
#        [1.29487181, 0.6777711 ],
#        [0.02109467, 4.2434023 ],
#        [1.39616366, 5.12999454],
#        [3.06266445, 1.03635986]])

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('/content/kmeans_student_dataset.xlsx')
df.head()
# Out:
#            IQ      CGPA  Cluster_Label
# 0   89.747965  6.012365              0
# 1   88.387764  6.199928              0
# 2   95.046202  1.527741              1
# 3   96.533123  1.017958              1
# 4  100.045507  8.087369              1

# %%
import matplotlib.pyplot as plt
plt.scatter(df['CGPA'],df['IQ'])

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

# %%
centriods=[(-5,-5),(5,5)]
cluster_std=[1,1]
x,y=make_blobs(n_samples=1000,centers=centriods,cluster_std=cluster_std,n_features=2,random_state=2)

# %%
import matplotlib.pyplot as plt

plt.scatter(x[:,0],x[:,1])

# %% [markdown]
# image sagmentation

# %%
 from sklearn.datasets import load_digits
X_digits, y_digits = load_digits(return_X_y=True)
X_train, y_train = X_digits[:1400], y_digits[:1400]
X_test, y_test = X_digits[1400:], y_digits[1400:]

# %%
from sklearn.linear_model import LogisticRegression
n_labeled = 50
log_reg = LogisticRegression(max_iter=10_000)
log_reg.fit(X_train[:n_labeled], y_train[:n_labeled])
# Out:
# LogisticRegression(max_iter=10000)

# %%
log_reg.score(X_test, y_test)
# Out:
# 0.7581863979848866

# %% [markdown]
# DBSCAN

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
x=np.array([[1,2],[2,2],[2,3],[8,7],[8,8],[25,80]])

# %%
import matplotlib.pyplot as plt
plt.scatter(x[:,0],x[:,1])

# %%
db=DBSCAN(eps=3,min_samples=2)
db.fit(x)
db.labels_
# Out:
# array([ 0,  0,  0,  1,  1, -1])

# %%
from sklearn.datasets import make_circles
x,_=make_circles(n_samples=500,factor=0.5,noise=0.05)
plt.scatter(x[:,0],x[:,1]  ,cmap='rainbow')
