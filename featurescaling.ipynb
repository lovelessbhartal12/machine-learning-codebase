# %% [markdown]
# <a href="https://colab.research.google.com/github/lovelessbhartal12/machine-learning-codebase/blob/main/featurescaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Social_Network_Ads.csv')
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# #Standarization

# %%
x=df.iloc[:,:2]
y=df.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchased, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_scaled=sc.fit_transform(x_train)
x_test_scaled=sc.transform(x_test)

# %%
data=pd.DataFrame(x_train_scaled)
data.head()
# Out:
#           0         1
# 0  1.922950  2.146016
# 1  2.020161  0.378719
# 2 -1.382215 -0.432499
# 3 -1.187794 -1.011940
# 4  1.922950 -0.925024

# %%
data.describe()
# Out:
#                   0           1
# count  3.200000e+02  320.000000
# mean   5.551115e-18    0.000000
# std    1.001566e+00    1.001566
# min   -1.965480e+00   -1.591382
# 25%   -7.989508e-01   -0.780164
# 50%   -2.126485e-02   -0.012404
# 75%    7.564211e-01    0.523580
# max    2.117372e+00    2.319848

# %% [markdown]
# #Why scaling is very important

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model1=LogisticRegression()

# %%
model.fit(x_train,y_train)
model1.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
y_pred1=model1.predict(x_test_scaled)

# %%
from sklearn.metrics import accuracy_score
print("accuracy in the non scale daata",accuracy_score(y_test,y_pred))
print("accuracy in the scale daata",accuracy_score(y_test,y_pred1))
# Out:
# accuracy in the non scale daata 0.925
# accuracy in the scale daata 0.925

# %%
df.describe()
# Out:
#               Age  EstimatedSalary   Purchased
# count  400.000000       400.000000  400.000000
# mean    37.655000     69742.500000    0.357500
# std     10.482877     34096.960282    0.479864
# min     18.000000     15000.000000    0.000000
# 25%     29.750000     43000.000000    0.000000
# 50%     37.000000     70000.000000    0.000000
# 75%     46.000000     88000.000000    1.000000
# max     60.000000    150000.000000    1.000000
