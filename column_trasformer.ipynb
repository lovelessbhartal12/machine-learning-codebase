# %% [markdown]
# <a href="https://colab.research.google.com/github/lovelessbhartal12/machine-learning-codebase/blob/main/column_trasformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/covid_toy.csv')
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(columns=['has_covid']),df['has_covid'],test_size=0.2)

# %%
X_train
# Out:
#     age  gender  fever   cough       city
# 55   81  Female  101.0    Mild     Mumbai
# 48   66    Male   99.0  Strong  Bangalore
# 45   72    Male   99.0    Mild  Bangalore
# 67   65    Male   99.0    Mild  Bangalore
# 33   26  Female   98.0    Mild    Kolkata
# ..  ...     ...    ...     ...        ...
# 92   82  Female  102.0  Strong    Kolkata
# 41   82    Male    NaN    Mild    Kolkata
# 73   34    Male   98.0  Strong    Kolkata
# 70   68  Female  101.0  Strong      Delhi
# 94   79    Male    NaN  Strong    Kolkata
#
# [80 rows x 5 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
transformer = ColumnTransformer(transformers=[
    # Impute 'fever' (numerical column) with default strategy='mean'
    ('tnf1', SimpleImputer(), ['fever']),

    # Encode 'cough' with order: Mild < Strong
    ('tnf2', OrdinalEncoder(categories=[['Mild', 'Strong']]), ['cough']),

    # One-hot encode 'gender' and 'city', drop first to avoid dummy variable trap
    ('tnf3', OneHotEncoder(sparse_output=False, drop='first'), ['gender', 'city'])

], remainder='passthrough')

# %%
x_train=transformer.fit_transform(X_train)
x_test=transformer.transform(X_test)

# %%
x_train
# Out:
# array([[101.       ,   0.       ,   0.       ,   0.       ,   0.       ,
#           1.       ,  81.       ],
#        [ 99.       ,   1.       ,   1.       ,   0.       ,   0.       ,
#           0.       ,  66.       ],
#        [ 99.       ,   0.       ,   1.       ,   0.       ,   0.       ,
#           0.       ,  72.       ],
#        [ 99.       ,   0.       ,   1.       ,   0.       ,   0.       ,
#           0.       ,  65.       ],
#        [ 98.       ,   0.       ,   0.       ,   0.       ,   1.       ,
#           0.       ,  26.       ],
#        [100.       ,   1.       ,   0.       ,   0.       ,   1.       ,
#           0.       ,  13.       ],
#        [100.       ,   0.       ,   1.       ,   0.       ,   1.       ,
#           0.       ,  27.       ],
#        [101.       ,   0.       ,   0.       ,   0.       ,   0.       ,
#           0.       ,  20.       ],
#        [100.8028169,   1.       ,   1.       ,   0.       ,   1.       ,
# ...
