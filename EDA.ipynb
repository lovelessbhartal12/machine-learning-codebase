# %% [markdown]
# <a href="https://colab.research.google.com/github/lovelessbhartal12/machine-learning-codebase/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #UNIVARIENT EDA

# %%
df=pd.read_csv('/content/datasets_11657_16098_train.xls')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df['Pclass'].value_counts().plot(kind='bar',color='blue')
# Out:
# <Axes: xlabel='Pclass'>

# %%
from enum import auto
import seaborn as sns
import matplotlib.pyplot as plt
df['Survived'].value_counts().plot(kind='pie',autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #in numerical data

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #displot

# %%
import seaborn as sns
sns.displot(df['Age'],bins=10,kde=True)

# %% [markdown]
# #box plot

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %% [markdown]
# #bivarient and mutivarient eda

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
trip=sns.load_dataset('tips')
trip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flight=sns.load_dataset('flights')
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# #scatter(numerical-numerical)

# %%
import seaborn as sns
sns.scatterplot(x=trip['total_bill'],y=trip['tip'],hue=trip['sex'],style=trip['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
titanic=pd.read_csv('/content/datasets_11657_16098_train.xls')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #boxplot(numerical-categorical)

# %%
sns.boxplot(x=titanic['Age'],y=titanic['Sex'],hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %% [markdown]
# #heatmap(categorical-categorical)

# %%
import pandas as pd
sns.heatmap(pd.crosstab(titanic['Sex'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>

# %% [markdown]
# #clustermap

# %%
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))
